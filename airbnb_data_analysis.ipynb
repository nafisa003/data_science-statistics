# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('AB_NYC_2019.csv')
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park   2787.0
# 1  2595                             Skylit Midtown Castle   2845.0
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !   4632.0
# 3  3831                   Cozy Entire Floor of Brownstone   4869.0
# 4  5022  Entire Apt: Spacious Studio/Loft by central park   7192.0
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.price.quantile(0.99)
# Out:
# 764.5

# %%
df.shape
# Out:
# (43427, 16)

# %%
sns.boxplot(df.price)
# Out:
# <Axes: >

# %%
sns.histplot(df.price)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
df[df.price>=8000]
# Out:
#              id                                               name  \
# 4377    2953058                                      Film Location
# 6530    4737930                                 Spanish Harlem Apt
# 9151    7003697                Furnished room in Astoria apartment
# 12342   9528920                Quiet, Clean, Lit @ LES & Chinatown
# 17692  13894339    Luxury 1 bedroom apt. -stunning Manhattan views
# 29238  22436899                                1-BR Lincoln Center
# 30268  23377410  Beautiful/Spacious 1 bed luxury flat-TriBeCa/Soho
# 40433  31340283  2br - The Heart of NYC: Manhattans Lower East ...
#
#           host_id host_name neighbourhood_group    neighbourhood  latitude  \
# 4377    1177497.0   Jessica            Brooklyn     Clinton Hill  40.69137
# 6530    1235070.0     Olson           Manhattan      East Harlem  40.79264
# 9151   20582832.0  Kathrine              Queens          Astoria  40.76810
# ...

# %%
df.price.quantile(0.8)
# Out:
# 196.0

# %%
df.price.describe()
# Out:
# count    43426.000000
# mean       149.571777
# std        237.780407
# min          0.000000
# 25%         69.000000
# 50%        105.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
new=df[df.price<=8000]
new.shape
# Out:
# (43419, 16)

# %%
new.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park   2787.0
# 1  2595                             Skylit Midtown Castle   2845.0
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !   4632.0
# 3  3831                   Cozy Entire Floor of Brownstone   4869.0
# 4  5022  Entire Apt: Spacious Studio/Loft by central park   7192.0
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
new.price.describe()
# Out:
# count    43419.000000
# mean       148.018310
# std        203.795789
# min          0.000000
# 25%         69.000000
# 50%        105.000000
# 75%        175.000000
# max       8000.000000
# Name: price, dtype: float64
